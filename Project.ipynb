# %% [markdown]
# <a href="https://colab.research.google.com/github/ThitiwatJtrsn/DWDM21/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # ทำงานกับข้อมูลลักษณะ ตาราง

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # จัดการไฟล์และ path

# %%
path = '/content/drive/My Drive/Project'

# %%
data01 = pd.read_csv(os.path.join(path,'importfertcountry-.csv'))
data01
# Out:
#       id                              Title  ...         Y2017 Y2018
# 0      1  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...  1,180,532.00   NaN
# 1      2  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...    949,696.61   NaN
# 2      3  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...    335,142.27   NaN
# 3      4  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...    654,577.16   NaN
# 4      5  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...    404,790.14   NaN
# ..   ...                                ...  ...           ...   ...
# 122  123  มูลค่าการนำเข้าปุ๋ยเคมีรายประเทศ   ...           NaN   NaN
# 123  124  มูลค่าการนำเข้าปุ๋ยเคมีรายประเทศ   ...           NaN   NaN
# 124  125  มูลค่าการนำเข้าปุ๋ยเคมีรายประเทศ   ...           NaN   NaN
# 125  126  มูลค่าการนำเข้าปุ๋ยเคมีรายประเทศ   ...  3,526,946.86   NaN
# 126  127  มูลค่าการนำเข้าปุ๋ยเคมีรายประเทศ   ...           NaN   NaN
#
# [127 rows x 19 columns]

# %%
data02 = pd.read_csv(os.path.join(path,'importpcidevol- .csv'))
data02
# Out:
#     id   ...              Y2020
# 0     1  ...       1,893,065.00
# 1     2  ...                 NaN
# 2     3  ...       2,501,570.96
# 3     4  ...       2,592,601.20
# 4     5  ...         463,530.00
# 5     6  ...         372,827.00
# 6     7  ...                 NaN
# 7     8  ...                 NaN
# 8     9  ...         919,208.00
# 9    10  ...         397,400.00
# 10   11  ...         703,783.00
# 11   12  ...                 NaN
# 12   13  ...                 NaN
# 13   14  ...                 NaN
# 14   15  ...         527,936.00
# 15   16  ...         422,001.00
# 16   17  ...     164,300,813.26
# 17   18  ...                 NaN
# 18   19  ...     357,910,666.15
# 19   20  ...     647,514,387.97
# 20   21  ...      64,923,759.44
# 21   22  ...   1,303,291,817.82
# 22   23  ...                 NaN
# 23   24  ...                 NaN
# 24   25  ...      64,998,715.06
# 25   26  ...      71,455,250.21
# 26   27  ...     108,790,649.31
# 27   28  ...                 NaN
# ...

# %%
data03 = pd.read_csv(os.path.join(path,'importplantcountry- .csv'))
data03
# Out:
#     id                             Title  ...      Y2019        Y2020
# 0    1  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...   6,909.40     6,849.32
# 1    2  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...   3,023.29     3,460.13
# 2    3  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...         NaN          NaN
# 3    4  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...   5,947.01    18,978.08
# 4    5  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...         NaN          NaN
# ..  ..                               ...  ...         ...          ...
# 91  92  มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...         NaN          NaN
# 92  93  มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...         NaN          NaN
# 93  94  มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...         NaN          NaN
# 94  95  มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...         NaN          NaN
# 95  96  มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...         NaN          NaN
#
# [96 rows x 21 columns]

# %%
data01.dropna()
# Out:
#     id                              Title  ...             Y2017             Y2018
# 6    7  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...        200,013.80         75,065.40
# 7    8  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...         30,216.83          4,292.37
# 8    9  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...        269,816.52        195,650.60
# 10  11  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...         57,580.12         51,819.16
# 11  12  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...            162.03            128.07
# 12  13  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...         46,376.21         79,850.77
# 14  15  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...         74,803.12         65,577.50
# 16  17  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...         60,971.94         63,381.83
# 17  18  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...          4,750.57          2,733.95
# 20  21  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...          2,105.40          1,017.40
# ...

# %%
data02.dropna()
# Out:
#     id   ...              Y2020
# 0     1  ...       1,893,065.00
# 2     3  ...       2,501,570.96
# 3     4  ...       2,592,601.20
# 4     5  ...         463,530.00
# 5     6  ...         372,827.00
# 8     9  ...         919,208.00
# 9    10  ...         397,400.00
# 10   11  ...         703,783.00
# 16   17  ...     164,300,813.26
# 18   19  ...     357,910,666.15
# 19   20  ...     647,514,387.97
# 20   21  ...      64,923,759.44
# 21   22  ...   1,303,291,817.82
# 24   25  ...      64,998,715.06
# 25   26  ...      71,455,250.21
# 26   27  ...     108,790,649.31
#
# [16 rows x 20 columns]

# %%
data03.dropna()
# Out:
#     id                             Title  ...            Y2019             Y2020
# 0    1  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...         6,909.40          6,849.32
# 3    4  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...         5,947.01         18,978.08
# 5    6  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...         9,152.59          8,830.02
# 8    9  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...       140,890.69        203,280.67
# 9   10  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...        37,915.23         42,485.37
# 10  11  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...       626,835.00        878,960.00
# 14  15  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...     1,922,077.73      1,994,106.49
# 16  17  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...        24,501.69         16,646.96
# 19  20  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...       476,361.96        541,051.90
# 20  21  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...            10.00             14.00
# 22  23  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...       919,139.50        862,245.60
# ...

# %% [markdown]
# ![ภาพถ่ายหน้าจอ 2564-08-27 เวลา 21.54.57.png](data:image/png;base64,...)

# %%
print(pd.concat([data01,data02],axis=1))
# Out:
#       id                              Title  ...           Y2019          Y2020
# 0      1  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...   2,249,075.00    1,893,065.00
# 1      2  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...     373,507.00              NaN
# 2      3  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...   2,274,394.04    2,501,570.96
# 3      4  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...   6,381,231.75    2,592,601.20
# 4      5  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...     299,800.00      463,530.00
# ..   ...                                ...  ...             ...             ...
# 122  123  มูลค่าการนำเข้าปุ๋ยเคมีรายประเทศ   ...             NaN             NaN
# 123  124  มูลค่าการนำเข้าปุ๋ยเคมีรายประเทศ   ...             NaN             NaN
# 124  125  มูลค่าการนำเข้าปุ๋ยเคมีรายประเทศ   ...             NaN             NaN
# 125  126  มูลค่าการนำเข้าปุ๋ยเคมีรายประเทศ   ...             NaN             NaN
# 126  127  มูลค่าการนำเข้าปุ๋ยเคมีรายประเทศ   ...             NaN             NaN
#
# ...

# %%
print(pd.concat([data01,data02,data03]))
# Out:
#       id                              Title  ...  Y2020   Y2019
# 0    1.0  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...     NaN     NaN
# 1    2.0  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...     NaN     NaN
# 2    3.0  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...     NaN     NaN
# 3    4.0  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...     NaN     NaN
# 4    5.0  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...     NaN     NaN
# ..   ...                                ...  ...     ...     ...
# 91  92.0   มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...     NaN     NaN
# 92  93.0   มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...     NaN     NaN
# 93  94.0   มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...     NaN     NaN
# 94  95.0   มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...     NaN     NaN
# 95  96.0   มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...     NaN     NaN
#
# [255 rows x 25 columns]

# %%
mixdata = pd.concat([data01,data02,data03])

# %%
mixdata
# Out:
#       id                              Title  ...  Y2020   Y2019
# 0    1.0  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...     NaN     NaN
# 1    2.0  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...     NaN     NaN
# 2    3.0  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...     NaN     NaN
# 3    4.0  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...     NaN     NaN
# 4    5.0  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ   ...     NaN     NaN
# ..   ...                                ...  ...     ...     ...
# 91  92.0   มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...     NaN     NaN
# 92  93.0   มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...     NaN     NaN
# 93  94.0   มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...     NaN     NaN
# 94  95.0   มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...     NaN     NaN
# 95  96.0   มูลค่าการนำเข้าเมล็ดพันธุ์ควบคุม  ...     NaN     NaN
#
# [255 rows x 25 columns]

# %%
mixdata.dropna()
# Out:
# Empty DataFrame
# Columns: [id, Title, Subtitle, Unit , View, Freq, Y2006, Y2007, Y2008, Y2009, Y2010, Y2011, Y2012, Y2013, Y2014, Y2015, Y2016, Y2017, Y2018, id , Unit,  View, Y2019,  Y2020 ,  Y2019 ]
# Index: []
